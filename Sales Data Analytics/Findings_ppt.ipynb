# %% [markdown]
# # Part II - Supermarket sales Data Exploration
# ## by j.zakaria

# %% [markdown]
# ## Investigation Overview
#
#
# In this investigation i aimed to see the characteristics that can make sales and profit for each branch of the market, i'm interessted in the gross profit and it's relationships with the oher features, and the categorical features that can make profit for each branch.
#
#
# ## Dataset Overview
#
# The growth of supermarkets in most populated cities are increasing and market competitions are also high. The dataset is one of the historical sales of
# supermarket company which has recorded in 3 different branches for 3 months
# data. Predictive data analytics methods are easy to apply with this dataset.
#
# Source kaggle: https://www.kaggle.com/datasets/aungpyaeap/supermarket-sales

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe, print statistics
sales = pd.read_csv('supermarket.csv')

# %% [markdown]
# > Note that the above cells have been set as "Skip"-type slides. That means
# that when the notebook is rendered as http slides, those cells won't show up.

# %% [markdown]
# ## Distribution of the gross profit
#
# The visualization of the raw gross income looks right skewed, it means the products with small prices contribute highly in the gross income (0-10) for each branch, the logarithmic scale shows that the distribution is normal with one peak in the middle so the value 25 is to most common in log scale.

# %% [markdown]
# ![image-1.png](01.png)  ![image-2.png](02.png)

# %% [markdown]
# ## Relationship between gross income and quantity and unit price for each branch
#
# As we see bewllow there is a positive relationship between the quantity, unit price, and gross income, if the 1st two are high, the gross income will be high too.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## How does the customer type impact the gross income
#
# Member or Normal customer, both of them can realise huge profit for the branches, there is no huge difference but just a little bit, members can realise high profit in the Branch A and B.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## How does the gender impact the gross income
#
# In general Female gender seems more profitable for all the branches, but there is not huge difference between the genders.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## How does the payement method impact the gross income
#
# In general Female gender seems more profitable for all the branches, but there is not huge difference between the genders.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Which product line is more profitable?
#
# There is no main profitable product line for all the branches, but each branch has it's profitable line, The Health and Beaty, Home and life style make the best sales for the Branch B, Food and beverages, sports and travel for the branch C, and Home and life style, fashion and accessories, sports and lifestyle for the branch A, however the sales of food and beverages are too small in the Branch A.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# !jupyter nbconvert part2.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook part2.ipynb to slides
# [NbConvertApp] Writing 898885 bytes to part2.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Serving your slides at http://127.0.0.1:8000/part2.slides.html
# Use Control-C to stop this server
# WARNING:tornado.access:404 GET /favicon.ico (127.0.0.1) 1.52ms
