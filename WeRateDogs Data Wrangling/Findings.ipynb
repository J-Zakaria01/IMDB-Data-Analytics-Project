# %% [markdown]
# ### Insights and Findings:
# First we will check the distributions of the Favorite count and the Retweet count, see the plots bellow:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# As we see there the data in the favorite count and retweet count colums is right skewed, that means there are many small values in the data and maybe many 0 values, in other terms we havemany outliers in the distribution of our data.

# %% [markdown]
# Now let's take a look at the Average count of favorites and retweets by source.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# In average the tweets posted by IPhone are getting more likes than the other sources. So we can say that the IPhone tweets are more popular. Now let's check the retweets.

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Again retweets count average is the higest for IPhone and Web Client sources, they are close is average, but much largeer than the TweetDeck source, so we can conclude that the IPhone tweets is the most popular source. Now let's analyse the prediction results.

# %% [markdown]
# Let's check the predictions results.

# %% [markdown]
# ![image.png](01.png "Title")

# %% [markdown]
# As we can see, in average the p1 conf have 60% confidence, 13.55% for p2, and 6.07% for p3, which means the 1st predictions are the best. Now let's check the accuracy.

# %% [markdown]
# For predictions 1:   78.82 % Accuracy.
#
# |  True  |  False |
# |--------|--------|
# |  629  |   169  |

# %% [markdown]
# For predictions 2:   79.32 % Accuracy.
#
# |  True  |  False |
# |--------|--------|
# |  633  |   165  |

# %% [markdown]
# For predictions 3:    76.81 % Accuracy.
#
# |  True  |  False |
# |--------|--------|
# |  613  |   185  |

# %% [markdown]
# In matter of accuracy we see that the 2nd prediction made 74.97 % which is the best accuracy rate, that means it predicted dogs more than the 1st and 2nd predictions, that's why it's the best prediction.
